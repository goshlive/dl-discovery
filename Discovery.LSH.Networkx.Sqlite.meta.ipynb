# %%
import time
import numpy as np

s_t = time.strftime("%H:%M:%S", time.localtime())
start_time = time.perf_counter()
print(f"Program META (Data: Sqlite) started at {s_t}")

#preparation
# %run Discovery.LSH.Networkx.Module.ipynb
directory = 'data\\sqlite\\'
max_size = np.inf
encoding='ISO-8859-1'
sep = ","
fresh = False
n_hash_fs=100
n_bands = 20
csv_infer, datasets, ini_nodes, init_edges, merge_nodes, merge_edges = prepare(directory, fresh, encoding=encoding, sep=sep, max_size=max_size, n_hash_fs=n_hash_fs, n_bands=n_bands)

#draw charts
max_metadata_length=100
untrained_model, trained_kfold_model, trained_shuffle_model, communities, community_labels, feature_vocab, X, y = \
draw_all(csv_infer, datasets, ini_nodes, init_edges, merge_nodes, merge_edges, encoding=encoding, sep=sep, max_metadata_length=max_metadata_length)

#redo metrics
random_state=50
train_kfold(community_labels, X, y)

test_size=0.75
random_state=100
train_shuffle(community_labels, X, y, test_size, random_state)


finish_time = time.perf_counter()
e_t = time.strftime("%H:%M:%S", time.localtime())
print(f"Program META (Data: Sqlite) finished at {e_t} in {(finish_time-start_time)/60} minutes")
# Out:
# Program META (Data: Sqlite) started at 10:12:14
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\goshl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# file datasets.pkl read successfully
# Function:get_zips() started at 10:12:21
# Function:get_zips() finished at 10:12:23 in 0.045288881666662444 minutes
# Function:get_zips() started at 10:12:24
# Function:get_zips() finished at 10:12:24 in 0.002556110000023182 minutes
# Function:LSH-based Similarity started at 10:12:25
# Processing total datasets: 1130
# Function:LSH-based Similarity finished at 10:16:43 in 4.30220959833332 minutes
# largest_shape == 240
# nbits == 2
# 1130 / 4 = 282.5, samples_buckets: 282.5, prev_samples_buckets:inf
# nbits == 4
# 1130 / 16 = 70.625, samples_buckets: 70.625, prev_samples_buckets:282.5
# nbits == 8
# 1130 / 256 = 4.4140625, samples_buckets: 4.4140625, prev_samples_buckets:70.625
# nbits == 16
# 1130 / 65536 = 0.017242431640625, samples_buckets: 0.017242431640625, prev_samples_buckets:4.4140625
# best_nbits == 8
# Number of nodes: 1130
# Number of edges: 239654
# 04-Sep-23 10:19:06 - Important nodes: 100
# 04-Sep-23 10:19:06 - testing setting 1 3 64
# 04-Sep-23 10:19:06 - Running TorchNetMF for a large window size...
# 04-Sep-23 10:19:06 - Window size is set to be 3
# 04-Sep-23 10:19:06 - Eigen decomposition...
# verbose default setting: False
# sparisfy default setting: True
# parallel_step default setting: 6
# prob_threshold (only for ppr_embedding) default setting: 0.0005
# community_range default setting: auto
# num_important (only for PPR) default setting: 100
# clustering_measure default setting: silhouette
# stopping default setting: 5
# improvement_step default setting: 0.05
# node_feature_type (netmf_embedding or ppr_embedding) default setting: netmf_embedding
# negative_range (negative sampling range) default setting: [1]
# window_sizes (range of netmf window sizes) default setting: [3]
# dims (latent dimension for netmf) default setting: [64]
# 04-Sep-23 10:19:22 - calinski_harabasz score: 4777.340193881088
# Fold 1 - Accuracy: 0.96018, Precision: 0.96153, Recall: 0.96018, F1-Score: 0.95787
#
# Average Metrics Across Folds:
# Average Accuracy: 0.19204
# Average Precision: 0.19231
# Average Recall: 0.19204
# Average F1-Score: 0.19157
# Fold 2 - Accuracy: 0.94690, Precision: 0.94879, Recall: 0.94690, F1-Score: 0.94464
#
# Average Metrics Across Folds:
# Average Accuracy: 0.38142
# Average Precision: 0.38207
# Average Recall: 0.38142
# Average F1-Score: 0.38050
# Fold 3 - Accuracy: 0.95133, Precision: 0.94524, Recall: 0.95133, F1-Score: 0.94753
#
# Average Metrics Across Folds:
# Average Accuracy: 0.57168
# Average Precision: 0.57111
# Average Recall: 0.57168
# Average F1-Score: 0.57001
# Fold 4 - Accuracy: 0.94248, Precision: 0.94531, Recall: 0.94248, F1-Score: 0.94204
#
# Average Metrics Across Folds:
# Average Accuracy: 0.76018
# Average Precision: 0.76017
# Average Recall: 0.76018
# Average F1-Score: 0.75842
# Fold 5 - Accuracy: 0.94248, Precision: 0.93551, Recall: 0.94248, F1-Score: 0.93849
#
# Average Metrics Across Folds:
# Average Accuracy: 0.94867
# Average Precision: 0.94728
# Average Recall: 0.94867
# Average F1-Score: 0.94612
# Accuracy: 0.9351
# Precision: 0.9250
# Recall: 0.9351
# F1-Score: 0.9290
# Confusion Matrix:
# [[ 0  4  0  0  0  0  0  0]
#  [ 0 26  0  0  0  0  0  0]
#  [ 0  0 66  2  2  1  0  0]
#  [ 0  0  0 15  0  0  0  0]
#  [ 0  0  0  0 43  0  0  0]
#  [ 0  0  4  0  0 54  0  6]
#  [ 0  0  0  0  0  0 31  0]
#  [ 0  0  0  0  0  3  0 82]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.87      1.00      0.93        26
#            2       0.94      0.93      0.94        71
#            3       0.88      1.00      0.94        15
#            4       0.96      1.00      0.98        43
#            5       0.93      0.84      0.89        64
#            6       1.00      1.00      1.00        31
#            7       0.93      0.96      0.95        85
#
#     accuracy                           0.94       339
#    macro avg       0.81      0.84      0.83       339
# weighted avg       0.93      0.94      0.93       339
#
# ROC AUC for Community 0: 0.9948
# ROC AUC for Community 1: 0.9991
# ROC AUC for Community 2: 0.9695
# ROC AUC for Community 3: 0.9971
# ROC AUC for Community 4: 1.0000
# ROC AUC for Community 5: 0.9426
# ROC AUC for Community 6: 1.0000
# ROC AUC for Community 7: 0.9931
# Confusion Matrix:
# [[ 0  4  0  0  0  0  0  0]
#  [ 0 26  0  0  0  0  0  0]
#  [ 0  0 66  2  2  1  0  0]
#  [ 0  0  0 15  0  0  0  0]
#  [ 0  0  0  0 43  0  0  0]
#  [ 0  0  4  0  0 54  0  6]
#  [ 0  0  0  0  0  0 31  0]
#  [ 0  0  0  0  0  3  0 82]]
# Fold 1 - Accuracy: 0.96018, Precision: 0.96153, Recall: 0.96018, F1-Score: 0.95787
#
# Average Metrics Across Folds:
# Average Accuracy: 0.19204
# Average Precision: 0.19231
# Average Recall: 0.19204
# Average F1-Score: 0.19157
# Fold 2 - Accuracy: 0.94690, Precision: 0.94879, Recall: 0.94690, F1-Score: 0.94464
#
# Average Metrics Across Folds:
# Average Accuracy: 0.38142
# Average Precision: 0.38207
# Average Recall: 0.38142
# Average F1-Score: 0.38050
# Fold 3 - Accuracy: 0.96903, Precision: 0.97052, Recall: 0.96903, F1-Score: 0.96854
#
# Average Metrics Across Folds:
# Average Accuracy: 0.57522
# Average Precision: 0.57617
# Average Recall: 0.57522
# Average F1-Score: 0.57421
# Fold 4 - Accuracy: 0.94248, Precision: 0.94531, Recall: 0.94248, F1-Score: 0.94204
#
# Average Metrics Across Folds:
# Average Accuracy: 0.76372
# Average Precision: 0.76523
# Average Recall: 0.76372
# Average F1-Score: 0.76262
# Fold 5 - Accuracy: 0.94690, Precision: 0.94029, Recall: 0.94690, F1-Score: 0.94292
#
# Average Metrics Across Folds:
# Average Accuracy: 0.95310
# Average Precision: 0.95329
# Average Recall: 0.95310
# Average F1-Score: 0.95120
# Accuracy: 0.9163
# Precision: 0.9164
# Recall: 0.9163
# F1-Score: 0.9144
# Confusion Matrix:
# [[  5   2   0   0   2   0   0   0]
#  [  0  65   0   0   0   0   0   0]
#  [  0   1 158   5   4  10   0   0]
#  [  0   0   0  33   0   4   0   0]
#  [  0   0   0   0 109   0   0   0]
#  [  0   0  19   0   0 138   4   0]
#  [  0   0   0   0   0   0  59  18]
#  [  0   0   0   0   0   2   0 210]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.56      0.71         9
#            1       0.96      1.00      0.98        65
#            2       0.89      0.89      0.89       178
#            3       0.87      0.89      0.88        37
#            4       0.95      1.00      0.97       109
#            5       0.90      0.86      0.88       161
#            6       0.94      0.77      0.84        77
#            7       0.92      0.99      0.95       212
#
#     accuracy                           0.92       848
#    macro avg       0.93      0.87      0.89       848
# weighted avg       0.92      0.92      0.91       848
#
# ROC AUC for Community 0: 0.9943
# ROC AUC for Community 1: 0.9979
# ROC AUC for Community 2: 0.9485
# ROC AUC for Community 3: 0.9972
# ROC AUC for Community 4: 1.0000
# ROC AUC for Community 5: 0.9554
# ROC AUC for Community 6: 0.9763
# ROC AUC for Community 7: 0.9930
# Confusion Matrix:
# [[  5   2   0   0   2   0   0   0]
#  [  0  65   0   0   0   0   0   0]
#  [  0   1 158   5   4  10   0   0]
#  [  0   0   0  33   0   4   0   0]
#  [  0   0   0   0 109   0   0   0]
#  [  0   0  19   0   0 138   4   0]
#  [  0   0   0   0   0   0  59  18]
#  [  0   0   0   0   0   2   0 210]]
# Program META (Data: Sqlite) finished at 10:31:20 in 19.106344096666664 minutes
